# %%
import torch

import torch.nn as nn

# Trainig data
x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

# Create Model
class MyModel (nn.Module):
    
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(1,1)
        
    def forward(self,x):
        return self.linear(x)
    
    
model = MyModel()


# Loss function
loss_function = nn.MSELoss()

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# Trainig
for epoch in range(500):
    
    # prediction
    y_pred = model(x)
    
    # Calculate loss
    loss = loss_function(y_pred, y)
    
    # Calculate gradients
    optimizer.zero_grad()
    loss.backward()
    
    # Update Parameters
    optimizer.step()
    
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Loss = {loss.item():.4f}")
    
# Test the model
with torch.no_grad():
        
    new_x = torch.tensor([[5.0]])
        
    prediction = model(new_x)
        
print("Prediction :", prediction.item())
# Out:
# Epoch 0: Loss = 17.9790
# Epoch 100: Loss = 0.0300
# Epoch 200: Loss = 0.0165
# Epoch 300: Loss = 0.0090
# Epoch 400: Loss = 0.0050
# Prediction : 9.9105224609375

# %%
import torch
import torch.nn as nn

# 4 samples, each sample has 1 feature
x = torch.tensor([
    [1.0],
    [2.0],
    [3.0],
    [4.0]
])

print("Input shape:", x.shape)

# 1 input feature → 1 output
layer = nn.Linear(1, 1)

output = layer(x)

print("Output shape:", output.shape)
print(output)
# Out:
# Input shape: torch.Size([4, 1])
# Output shape: torch.Size([4, 1])
# tensor([[-0.0701],
#         [-0.9844],
#         [-1.8987],
#         [-2.8131]], grad_fn=<AddmmBackward0>)

# %%
# Activation(RELU)
import torch

x = torch.tensor([-8.,4,-2,-3])

output = torch.relu(x)

print(output)
# Out:
# tensor([0., 4., 0., 0.])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class MyModel (nn.Module):
    
    def __init__(self):    #Ye model ke parts/layers banane ki jagah hai.
        super().__init__() #nn.Module ke basic setup ko initialize karta hai.
        
        self.Linear = nn.Linear(1,1)  #Yahan hum model ke andar ek Linear Layer bana rahe hain.
        
    def forward(self, x):  #"Input x model ke andar kis route se jayega?
        return self.Linear(x)
    
x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])
    
model = MyModel()
    
loss_function = nn.MSELoss()
    
optimizer = optim.Adam(model.parameters(), lr = 0.1)
    
for epoch in range(10):
        
    optimizer.zero_grad()
    y_pred = model(x)
    loss = loss_function(y_pred,y)
    loss.backward()
        
    optimizer.step()
    
    print(f"Epoch {epoch +1}, Loss = {loss.item():.4f}")        
    
torch.save(model. state_dict(), "model.pth")
print("Model saved Successfully!")
# Out:
# Epoch 1, Loss = 20.4512
# Epoch 2, Loss = 17.2738
# Epoch 3, Loss = 14.3750
# Epoch 4, Loss = 11.7587
# Epoch 5, Loss = 9.4267
# Epoch 6, Loss = 7.3789
# Epoch 7, Loss = 5.6123
# Epoch 8, Loss = 4.1212
# Epoch 9, Loss = 2.8962
# Epoch 10, Loss = 1.9243
# Model saved Successfully!
