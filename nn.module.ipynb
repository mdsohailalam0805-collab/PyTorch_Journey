# %%
import torch

import torch.nn as nn

# Trainig data
x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

# Create Model
class MyModel (nn.Module):
    
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(1,1)
        
    def forward(self,x):
        return self.linear(x)
    
    
model = MyModel()


# Loss function
loss_function = nn.MSELoss()

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# Trainig
for epoch in range(500):
    
    # prediction
    y_pred = model(x)
    
    # Calculate loss
    loss = loss_function(y_pred, y)
    
    # Calculate gradients
    optimizer.zero_grad()
    loss.backward()
    
    # Update Parameters
    optimizer.step()
    
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Loss = {loss.item():.4f}")
    
# Test the model
with torch.no_grad():
        
    new_x = torch.tensor([[5.0]])
        
    prediction = model(new_x)
        
print("Prediction :", prediction.item())
# Out:
# Epoch 0: Loss = 11.4688
# Epoch 100: Loss = 0.0743
# Epoch 200: Loss = 0.0408
# Epoch 300: Loss = 0.0224
# Epoch 400: Loss = 0.0123
# Prediction : 9.859132766723633

# %%
import torch
import torch.nn as nn

# 4 samples, each sample has 1 feature
x = torch.tensor([
    [1.0],
    [2.0],
    [3.0],
    [4.0]
])

print("Input shape:", x.shape)

# 1 input feature → 1 output
layer = nn.Linear(1, 1)

output = layer(x)

print("Output shape:", output.shape)
print(output)
# Out:
# Input shape: torch.Size([4, 1])
# Output shape: torch.Size([4, 1])
# tensor([[1.2649],
#         [1.9441],
#         [2.6233],
#         [3.3024]], grad_fn=<AddmmBackward0>)

# %%
# Activation(RELU)
import torch

x = torch.tensor([-8.,4,-2,-3])

output = torch.relu(x)

print(output)
# Out:
# tensor([0., 4., 0., 0.])
