# %%
import torch
import torch.nn as nn

# Trainig data
x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

# Create Model
class MyModel (nn.Module):
    
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(1,1)
        
    def forward(self,x):
        return self.linear(x)
    
    
model = MyModel()


# Loss function
loss_function = nn.MSELoss()

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# Trainig
for epoch in range(1000):
    
    # prediction
    y_pred = model(x)
    
    # Calculate loss
    loss = loss_function(y_pred, y)
    
    # Calculate gradients
    optimizer.zero_grad()
    loss.backward()
    
    # Update Parameters
    optimizer.step()
    
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Loss = {loss.item():.4f}")
    
# Test the model
with torch.no_grad():
        
    new_x = torch.tensor([[5.0]])
        
    prediction = model(new_x)
        
print("Prediction :", prediction.item())
# Out:
# Epoch 0: Loss = 30.0732
# Epoch 100: Loss = 0.1577
# Epoch 200: Loss = 0.0866
# Epoch 300: Loss = 0.0475
# Epoch 400: Loss = 0.0261
# Epoch 500: Loss = 0.0143
# Epoch 600: Loss = 0.0079
# Epoch 700: Loss = 0.0043
# Epoch 800: Loss = 0.0024
# Epoch 900: Loss = 0.0013
# Prediction : 9.954174995422363
